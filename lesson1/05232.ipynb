# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(1,5):
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
for i in range(1,5,2):
    print(i)
# Out:
# 1
# 3

# %%
i=0
i+=1
i+=2
i+=3
i+=4
i+=5
i+=6
i+=7
i+=8
i+=9
i+=10

print(i)
# Out:
# 55

# %%
total=0
for i in range(1,101):
    total +=i

print(total)
# Out:
# 5050

# %%
try:
    score = int(input("fill score:"))

    if score >= 90:
        print("A")
    elif score >= 80:
        print("B")
    elif score >= 70:
        print("C")
    elif score >= 60:
        print("D")
    else:
        print("F")

except ValueError:
    print("GG")
# Out:
# GG
